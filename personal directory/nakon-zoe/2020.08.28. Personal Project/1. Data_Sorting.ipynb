# %%
import pandas as pd

# %% [markdown]
# # Sorting

# %%
df_2019팀타자 = pd.read_csv('1. OriginalDatasets/2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2019.csv')
df_2019팀타자 = df_2019팀타자.sort_values(by=['T_ID', 'GDAY_DS', 'VS_T_ID'], ascending=True)
df_2019팀타자.to_csv('2. SortedDatasets/SORTED_2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2019.csv', index = False, encoding = 'cp949')

df_2019팀투수 = pd.read_csv('1. OriginalDatasets/2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2019.csv')
df_2019팀투수 = df_2019팀투수.sort_values(by=['T_ID', 'GDAY_DS', 'VS_T_ID'], ascending=True)
df_2019팀투수.to_csv('2. SortedDatasets/SORTED_2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2019.csv', index = False, encoding = 'cp949')

df_2018팀타자 = pd.read_csv('1. OriginalDatasets/2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2018.csv')
df_2018팀타자 = df_2018팀타자.sort_values(by=['T_ID', 'GDAY_DS', 'VS_T_ID'], ascending=True)
df_2018팀타자.to_csv('2. SortedDatasets/SORTED_2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2018.csv', index = False, encoding = 'cp949')

df_2018팀투수 = pd.read_csv('1. OriginalDatasets/2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2018.csv')
df_2018팀투수 = df_2018팀투수.sort_values(by=['T_ID', 'GDAY_DS', 'VS_T_ID'], ascending=True)
df_2018팀투수.to_csv('2. SortedDatasets/SORTED_2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2018.csv', index = False, encoding = 'cp949')

df_2017팀타자 = pd.read_csv('1. OriginalDatasets/2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2017.csv')
df_2017팀타자 = df_2017팀타자.sort_values(by=['T_ID', 'GDAY_DS', 'VS_T_ID'], ascending=True)
df_2017팀타자.to_csv('2. SortedDatasets/SORTED_2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2017.csv', index = False, encoding = 'cp949')

df_2017팀투수 = pd.read_csv('1. OriginalDatasets/2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2017.csv')
df_2017팀투수 = df_2017팀투수.sort_values(by=['T_ID', 'GDAY_DS', 'VS_T_ID'], ascending=True)
df_2017팀투수.to_csv('2. SortedDatasets/SORTED_2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2017.csv', index = False, encoding = 'cp949')

df_2016팀타자 = pd.read_csv('1. OriginalDatasets/2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2016.csv')
df_2016팀타자 = df_2016팀타자.sort_values(by=['T_ID', 'GDAY_DS', 'VS_T_ID'], ascending=True)
df_2016팀타자.to_csv('2. SortedDatasets/SORTED_2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2016.csv', index = False, encoding = 'cp949')

df_2016팀투수 = pd.read_csv('1. OriginalDatasets/2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2016.csv')
df_2016팀투수 = df_2016팀투수.sort_values(by=['T_ID', 'GDAY_DS', 'VS_T_ID'], ascending=True)
df_2016팀투수.to_csv('2. SortedDatasets/SORTED_2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2016.csv', index = False, encoding = 'cp949')

# %%
df_2019팀타자
# Out:
#                G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  PA  AB  RBI  RUN  \
# 0     20190323HHOB0  20190323   HH      OB          0     T  42  34    4    4
# 10    20190324HHOB0  20190324   HH      OB          0     T  43  37   10   11
# 20    20190326HHHT0  20190326   HH      HT          0     T  46  38   13   13
# 30    20190327HHHT0  20190327   HH      HT          0     T  40  35    4    4
# 40    20190328HHHT0  20190328   HH      HT          0     T  33  30    4    4
# ...             ...       ...  ...     ...        ...   ...  ..  ..  ...  ...
# 1355  20190917WOHH0  20190917   WO      HH          0     T  31  30    0    0
# 1377  20190920WOSK0  20190920   WO      SK          0     T  39  33    5    5
# 1397  20190924WOHT0  20190924   WO      HT          0     T  35  34    0    0
# 1431  20190929WOLT0  20190929   WO      LT          0     T  37  32    4    4
# 1439  20191001WOLT0  20191001   WO      LT          0     T  38  35    2    3
#
# ...

# %%
df_2019팀투수
# Out:
#                G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  CG_CK WLS  HOLD  \
# 1     20190323HHOB0  20190323   HH      OB          0     T      0   L     0
# 11    20190324HHOB0  20190324   HH      OB          0     T      0   W     0
# 21    20190326HHHT0  20190326   HH      HT          0     T      0   W     1
# 31    20190327HHHT0  20190327   HH      HT          0     T      0   L     0
# 41    20190328HHHT0  20190328   HH      HT          0     T      0   L     0
# ...             ...       ...  ...     ...        ...   ...    ...  ..   ...
# 1355  20190917WOHH0  20190917   WO      HH          0     T      0   L     0
# 1377  20190920WOSK0  20190920   WO      SK          0     T      0   W     1
# 1397  20190924WOHT0  20190924   WO      HT          0     T      0   L     0
# 1431  20190929WOLT0  20190929   WO      LT          0     T      0   W     2
# 1439  20191001WOLT0  20191001   WO      LT          0     T      0   W     5
#
# ...

# %%
df_2018팀타자
# Out:
#                G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  PA  AB  RBI  RUN  \
# 1     20180324HHWO0  20180324   HH      WO          0     T  38  37    2    3
# 11    20180325HHWO0  20180325   HH      WO          0     T  39  36    4    4
# 21    20180327HHNC0  20180327   HH      NC          0     T  41  34    6    6
# 31    20180328HHNC0  20180328   HH      NC          0     T  41  37    6    6
# 41    20180329HHNC0  20180329   HH      NC          0     T  35  33    1    1
# ...             ...       ...  ...     ...        ...   ...  ..  ..  ...  ...
# 1358  20180929NCWO0  20180929   WO      NC          0     B  38  37    6    6
# 1368  20180930NCWO0  20180930   WO      NC          0     B  34  32    8    8
# 1399  20181006WONC0  20181006   WO      NC          0     T  41  35    5    5
# 1427  20181012WOKT0  20181012   WO      KT          0     T  43  41    9   10
# 1437  20181013WOSS0  20181013   WO      SS          0     T  38  35    5    5
#
# ...

# %%
df_2018팀투수
# Out:
#                G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  CG_CK WLS  HOLD  \
# 1     20180324HHWO0  20180324   HH      WO          0     T      0   L     0
# 11    20180325HHWO0  20180325   HH      WO          0     T      0   W     1
# 21    20180327HHNC0  20180327   HH      NC          0     T      0   L     0
# 31    20180328HHNC0  20180328   HH      NC          0     T      0   W     0
# 41    20180329HHNC0  20180329   HH      NC          0     T      0   L     3
# ...             ...       ...  ...     ...        ...   ...    ...  ..   ...
# 1358  20180929NCWO0  20180929   WO      NC          0     B      0   W     0
# 1368  20180930NCWO0  20180930   WO      NC          0     B      0   W     0
# 1399  20181006WONC0  20181006   WO      NC          0     T      0   L     2
# 1427  20181012WOKT0  20181012   WO      KT          0     T      0   W     2
# 1437  20181013WOSS0  20181013   WO      SS          0     T      0   L     0
#
# ...

# %%
df_2017팀타자
# Out:
#                G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  PA  AB  RBI  RUN  \
# 1     20170331HHOB0  20170331   HH      OB          0     T  33  29    0    0
# 11    20170401HHOB0  20170401   HH      OB          0     T  54  44    6    6
# 21    20170402HHOB0  20170402   HH      OB          0     T  54  44    4    4
# 30    20170404NCHH0  20170404   HH      NC          0     B  37  31    6    6
# 40    20170406NCHH0  20170406   HH      NC          0     B  37  34    2    2
# ...             ...       ...  ...     ...        ...   ...  ..  ..  ...  ...
# 1375  20170921WOKT0  20170921   WO      KT          0     T  41  36    5    5
# 1389  20170923WOLT0  20170923   WO      LT          0     T  35  35    2    2
# 1415  20170929WONC0  20170929   WO      NC          0     T  42  40    4    4
# 1421  20170930WONC0  20170930   WO      NC          0     T  35  34    4    4
# 1439  20171003WOSS0  20171003   WO      SS          0     T  45  41    8    9
#
# ...

# %%
df_2017팀투수
# Out:
#                G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  CG_CK WLS  HOLD  \
# 1     20170331HHOB0  20170331   HH      OB          0     T      0   L     0
# 11    20170401HHOB0  20170401   HH      OB          0     T      0   W     0
# 21    20170402HHOB0  20170402   HH      OB          0     T      0   L     0
# 30    20170404NCHH0  20170404   HH      NC          0     B      0   W     0
# 40    20170406NCHH0  20170406   HH      NC          0     B      0   L     0
# ...             ...       ...  ...     ...        ...   ...    ...  ..   ...
# 1375  20170921WOKT0  20170921   WO      KT          0     T      0   W     0
# 1389  20170923WOLT0  20170923   WO      LT          0     T      0   L     0
# 1415  20170929WONC0  20170929   WO      NC          0     T      0   L     0
# 1421  20170930WONC0  20170930   WO      NC          0     T      0   L     0
# 1439  20171003WOSS0  20171003   WO      SS          0     T      0   L     0
#
# ...

# %%
df_2016팀타자
# Out:
#                G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  PA  AB  RBI  RUN  \
# 1     20160401HHLG0  20160401   HH      LG          0     T  52  46    4    4
# 11    20160402HHLG0  20160402   HH      LG          0     T  50  43    7    7
# 32    20160405WOHH0  20160405   HH      WO          0     B  41  35    8    9
# 40    20160406WOHH0  20160406   HH      WO          0     B  36  35    4    4
# 50    20160407WOHH0  20160407   HH      WO          0     B  40  39    3    3
# ...             ...       ...  ...     ...        ...   ...  ..  ..  ...  ...
# 1401  20161002WOHH0  20161002   WO      HH          0     T  41  38    4    4
# 1413  20161004WONC0  20161004   WO      NC          0     T  37  33    3    3
# 1419  20161005WONC0  20161005   WO      NC          0     T  35  34    4    4
# 1429  20161007WOLT0  20161007   WO      LT          0     T  38  32    4    4
# 1439  20161009WOLT0  20161009   WO      LT          0     T  38  33    5    5
#
# ...

# %%
df_2016팀투수
# Out:
#                G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  CG_CK WLS  HOLD  \
# 1     20160401HHLG0  20160401   HH      LG          0     T      0   L     0
# 11    20160402HHLG0  20160402   HH      LG          0     T      0   L     0
# 32    20160405WOHH0  20160405   HH      WO          0     B      0   W     0
# 40    20160406WOHH0  20160406   HH      WO          0     B      0   L     0
# 50    20160407WOHH0  20160407   HH      WO          0     B      0   L     0
# ...             ...       ...  ...     ...        ...   ...    ...  ..   ...
# 1401  20161002WOHH0  20161002   WO      HH          0     T      0   W     2
# 1413  20161004WONC0  20161004   WO      NC          0     T      0   W     0
# 1419  20161005WONC0  20161005   WO      NC          0     T      0   L     0
# 1429  20161007WOLT0  20161007   WO      LT          0     T      0   L     0
# 1439  20161009WOLT0  20161009   WO      LT          0     T      0   L     0
#
# ...
