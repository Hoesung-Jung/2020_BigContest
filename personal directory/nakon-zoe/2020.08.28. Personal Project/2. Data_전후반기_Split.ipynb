# %%
import pandas as pd

# %% [markdown]
# # 2019 Split

# %%
df = pd.read_excel('3. SplitedDatasets/Original/2019_TotalData.xlsx')
df
# Out:
#       yearID T_ID  gameNO   GDAY_DS VS_T_ID  HEADER_NO TB_SC  CG_CK  HOLD  \
# 0       2019   HH       1  20190323      OB          0     T      0     0
# 1       2019   HH       2  20190324      OB          0     T      0     0
# 2       2019   HH       3  20190326      HT          0     T      0     1
# 3       2019   HH       4  20190327      HT          0     T      0     0
# 4       2019   HH       5  20190328      HT          0     T      0     0
# ...      ...  ...     ...       ...     ...        ...   ...    ...   ...
# 1435    2019   WO     140  20190917      HH          0     T      0     0
# 1436    2019   WO     141  20190920      SK          0     T      0     1
# 1437    2019   WO     142  20190924      HT          0     T      0     0
# 1438    2019   WO     143  20190929      LT          0     T      0     2
# 1439    2019   WO     144  20191001      LT          0     T      0     5
#
#       INN2  ...  IB_B  HP_B  KK_B  GD_B  ERR_B  LOB_B  P_HRA_RT_B  P_AB_CN_B  \
# ...

# %%
del_list_post=[]; del_list_pre=[];
for i in range(len(df)):
    if df['gameNO'][i]>113:
        del_list_post.append(i)
    else:
        del_list_pre.append(i)

# %%
df_pre = df.drop(del_list_post)
df_pre
# Out:
#       yearID T_ID  gameNO   GDAY_DS VS_T_ID  HEADER_NO TB_SC  CG_CK  HOLD  \
# 0       2019   HH       1  20190323      OB          0     T      0     0
# 1       2019   HH       2  20190324      OB          0     T      0     0
# 2       2019   HH       3  20190326      HT          0     T      0     1
# 3       2019   HH       4  20190327      HT          0     T      0     0
# 4       2019   HH       5  20190328      HT          0     T      0     0
# ...      ...  ...     ...       ...     ...        ...   ...    ...   ...
# 1404    2019   WO     109  20190809      SK          0     B      0     0
# 1405    2019   WO     110  20190810      OB          0     B      0     0
# 1406    2019   WO     111  20190811      OB          0     B      0     0
# 1407    2019   WO     112  20190813      LG          0     T      0     0
# 1408    2019   WO     113  20190814      LG          0     T      0     0
#
#       INN2  ...  IB_B  HP_B  KK_B  GD_B  ERR_B  LOB_B  P_HRA_RT_B  P_AB_CN_B  \
# ...

# %%
df_post = df.drop(del_list_pre)
df_post
# Out:
#       yearID T_ID  gameNO   GDAY_DS VS_T_ID  HEADER_NO TB_SC  CG_CK  HOLD  \
# 113     2019   HH     114  20190818      WO          0     T      0     1
# 114     2019   HH     115  20190820      SS          0     B      0     0
# 115     2019   HH     116  20190822      SK          0     T      0     1
# 116     2019   HH     117  20190823      SK          0     T      0     0
# 117     2019   HH     118  20190824      OB          0     B      0     0
# ...      ...  ...     ...       ...     ...        ...   ...    ...   ...
# 1435    2019   WO     140  20190917      HH          0     T      0     0
# 1436    2019   WO     141  20190920      SK          0     T      0     1
# 1437    2019   WO     142  20190924      HT          0     T      0     0
# 1438    2019   WO     143  20190929      LT          0     T      0     2
# 1439    2019   WO     144  20191001      LT          0     T      0     5
#
#       INN2  ...  IB_B  HP_B  KK_B  GD_B  ERR_B  LOB_B  P_HRA_RT_B  P_AB_CN_B  \
# ...

# %%
df_pre.to_csv('3. SplitedDatasets/2019_pre.csv', index = False, encoding = 'cp949')
df_post.to_csv('3. SplitedDatasets/2019_post.csv', index = False, encoding = 'cp949')

# %% [markdown]
# # 2018 Split

# %%
df = pd.read_excel('3. SplitedDatasets/Original/2018_TotalData.xlsx')
df
# Out:
#       yearID T_ID  gameNO   GDAY_DS VS_T_ID  HEADER_NO TB_SC  CG_CK  HOLD  \
# 0       2018   HH       1  20180324      WO          0     T      0     0
# 1       2018   HH       2  20180325      WO          0     T      0     1
# 2       2018   HH       3  20180327      NC          0     T      0     0
# 3       2018   HH       4  20180328      NC          0     T      0     0
# 4       2018   HH       5  20180329      NC          0     T      0     3
# ...      ...  ...     ...       ...     ...        ...   ...    ...   ...
# 1435    2018   WO     140  20180929      NC          0     B      0     0
# 1436    2018   WO     141  20180930      NC          0     B      0     0
# 1437    2018   WO     142  20181006      NC          0     T      0     2
# 1438    2018   WO     143  20181012      KT          0     T      0     2
# 1439    2018   WO     144  20181013      SS          0     T      0     0
#
#       INN2  ...  IB_B  HP_B  KK_B  GD_B  ERR_B  LOB_B  P_HRA_RT_B  P_AB_CN_B  \
# ...

# %%
del_list_post=[]; del_list_pre=[];
for i in range(len(df)):
    if df['gameNO'][i]>113:
        del_list_post.append(i)
    else:
        del_list_pre.append(i)

# %%
df_pre = df.drop(del_list_post)
df_pre
# Out:
#       yearID T_ID  gameNO   GDAY_DS VS_T_ID  HEADER_NO TB_SC  CG_CK  HOLD  \
# 0       2018   HH       1  20180324      WO          0     T      0     0
# 1       2018   HH       2  20180325      WO          0     T      0     1
# 2       2018   HH       3  20180327      NC          0     T      0     0
# 3       2018   HH       4  20180328      NC          0     T      0     0
# 4       2018   HH       5  20180329      NC          0     T      0     3
# ...      ...  ...     ...       ...     ...        ...   ...    ...   ...
# 1404    2018   WO     109  20180805      KT          0     T      0     0
# 1405    2018   WO     110  20180807      HT          0     B      0     1
# 1406    2018   WO     111  20180808      HT          0     B      0     0
# 1407    2018   WO     112  20180809      HH          0     T      0     0
# 1408    2018   WO     113  20180810      HH          0     T      0     1
#
#       INN2  ...  IB_B  HP_B  KK_B  GD_B  ERR_B  LOB_B  P_HRA_RT_B  P_AB_CN_B  \
# ...

# %%
df_post = df.drop(del_list_pre)
df_post
# Out:
#       yearID T_ID  gameNO   GDAY_DS VS_T_ID  HEADER_NO TB_SC  CG_CK  HOLD  \
# 113     2018   HH     114  20180816      SS          0     T      0     0
# 114     2018   HH     115  20180904      LT          0     B      0     2
# 115     2018   HH     116  20180905      LT          0     B      0     2
# 116     2018   HH     117  20180906      KT          0     T      0     0
# 117     2018   HH     118  20180907      KT          0     T      0     0
# ...      ...  ...     ...       ...     ...        ...   ...    ...   ...
# 1435    2018   WO     140  20180929      NC          0     B      0     0
# 1436    2018   WO     141  20180930      NC          0     B      0     0
# 1437    2018   WO     142  20181006      NC          0     T      0     2
# 1438    2018   WO     143  20181012      KT          0     T      0     2
# 1439    2018   WO     144  20181013      SS          0     T      0     0
#
#       INN2  ...  IB_B  HP_B  KK_B  GD_B  ERR_B  LOB_B  P_HRA_RT_B  P_AB_CN_B  \
# ...

# %%
df_pre.to_csv('3. SplitedDatasets/2018_pre.csv', index = False, encoding = 'cp949')
df_post.to_csv('3. SplitedDatasets/2018_post.csv', index = False, encoding = 'cp949')

# %% [markdown]
# # 2017 Split

# %%
df = pd.read_excel('3. SplitedDatasets/Original/2017_TotalData.xlsx')
df
# Out:
#       yearID T_ID  gameNO   GDAY_DS VS_T_ID  HEADER_NO TB_SC  CG_CK  HOLD  \
# 0       2017   HH       1  20170331      OB          0     T      0     0
# 1       2017   HH       2  20170401      OB          0     T      0     0
# 2       2017   HH       3  20170402      OB          0     T      0     0
# 3       2017   HH       4  20170404      NC          0     B      0     0
# 4       2017   HH       5  20170406      NC          0     B      0     0
# ...      ...  ...     ...       ...     ...        ...   ...    ...   ...
# 1435    2017   WO     140  20170921      KT          0     T      0     0
# 1436    2017   WO     141  20170923      LT          0     T      0     0
# 1437    2017   WO     142  20170929      NC          0     T      0     0
# 1438    2017   WO     143  20170930      NC          0     T      0     0
# 1439    2017   WO     144  20171003      SS          0     T      0     0
#
#       INN2  ...  IB_B  HP_B  KK_B  GD_B  ERR_B  LOB_B  P_HRA_RT_B  P_AB_CN_B  \
# ...

# %%
del_list_post=[]; del_list_pre=[];
for i in range(len(df)):
    if df['gameNO'][i]>113:
        del_list_post.append(i)
    else:
        del_list_pre.append(i)

# %%
df_pre = df.drop(del_list_post)
df_pre
# Out:
#       yearID T_ID  gameNO   GDAY_DS VS_T_ID  HEADER_NO TB_SC  CG_CK  HOLD  \
# 0       2017   HH       1  20170331      OB          0     T      0     0
# 1       2017   HH       2  20170401      OB          0     T      0     0
# 2       2017   HH       3  20170402      OB          0     T      0     0
# 3       2017   HH       4  20170404      NC          0     B      0     0
# 4       2017   HH       5  20170406      NC          0     B      0     0
# ...      ...  ...     ...       ...     ...        ...   ...    ...   ...
# 1404    2017   WO     109  20170812      HH          0     B      0     0
# 1405    2017   WO     110  20170813      HH          0     B      0     0
# 1406    2017   WO     111  20170816      SS          0     T      0     3
# 1407    2017   WO     112  20170817      LT          0     B      0     0
# 1408    2017   WO     113  20170818      LT          0     B      0     2
#
#       INN2  ...  IB_B  HP_B  KK_B  GD_B  ERR_B  LOB_B  P_HRA_RT_B  P_AB_CN_B  \
# ...

# %%
df_post = df.drop(del_list_pre)
df_post
# Out:
#       yearID T_ID  gameNO   GDAY_DS VS_T_ID  HEADER_NO TB_SC  CG_CK  HOLD  \
# 113     2017   HH     114  20170825      HT          0     B      0     0
# 114     2017   HH     115  20170826      SK          0     T      0     0
# 115     2017   HH     116  20170827      SK          0     T      0     0
# 116     2017   HH     117  20170829      LG          0     B      0     1
# 117     2017   HH     118  20170830      LG          0     B      0     1
# ...      ...  ...     ...       ...     ...        ...   ...    ...   ...
# 1435    2017   WO     140  20170921      KT          0     T      0     0
# 1436    2017   WO     141  20170923      LT          0     T      0     0
# 1437    2017   WO     142  20170929      NC          0     T      0     0
# 1438    2017   WO     143  20170930      NC          0     T      0     0
# 1439    2017   WO     144  20171003      SS          0     T      0     0
#
#       INN2  ...  IB_B  HP_B  KK_B  GD_B  ERR_B  LOB_B  P_HRA_RT_B  P_AB_CN_B  \
# ...

# %%
df_pre.to_csv('3. SplitedDatasets/2017_pre.csv', index = False, encoding = 'cp949')
df_post.to_csv('3. SplitedDatasets/2017_post.csv', index = False, encoding = 'cp949')

# %% [markdown]
# # 2016 Split

# %%
df = pd.read_excel('3. SplitedDatasets/Original/2016_TotalData.xlsx')
df
# Out:
#       yearID T_ID  gameNO   GDAY_DS VS_T_ID  HEADER_NO TB_SC  CG_CK  HOLD  \
# 0       2016   HH       1  20160401      LG          0     T      0     0
# 1       2016   HH       2  20160402      LG          0     T      0     0
# 2       2016   HH       3  20160405      WO          0     B      0     0
# 3       2016   HH       4  20160406      WO          0     B      0     0
# 4       2016   HH       5  20160407      WO          0     B      0     0
# ...      ...  ...     ...       ...     ...        ...   ...    ...   ...
# 1435    2016   WO     140  20161002      HH          0     T      0     2
# 1436    2016   WO     141  20161004      NC          0     T      0     0
# 1437    2016   WO     142  20161005      NC          0     T      0     0
# 1438    2016   WO     143  20161007      LT          0     T      0     0
# 1439    2016   WO     144  20161009      LT          0     T      0     0
#
#       INN2  ...  IB_B  HP_B  KK_B  GD_B  ERR_B  LOB_B  P_HRA_RT_B  P_AB_CN_B  \
# ...

# %%
del_list_post=[]; del_list_pre=[];
for i in range(len(df)):
    if df['gameNO'][i]>113:
        del_list_post.append(i)
    else:
        del_list_pre.append(i)

# %%
df_pre = df.drop(del_list_post)
df_pre
# Out:
#       yearID T_ID  gameNO   GDAY_DS VS_T_ID  HEADER_NO TB_SC  CG_CK  HOLD  \
# 0       2016   HH       1  20160401      LG          0     T      0     0
# 1       2016   HH       2  20160402      LG          0     T      0     0
# 2       2016   HH       3  20160405      WO          0     B      0     0
# 3       2016   HH       4  20160406      WO          0     B      0     0
# 4       2016   HH       5  20160407      WO          0     B      0     0
# ...      ...  ...     ...       ...     ...        ...   ...    ...   ...
# 1404    2016   WO     109  20160818      NC          0     B      0     0
# 1405    2016   WO     110  20160819      NC          0     B      0     0
# 1406    2016   WO     111  20160820      SS          0     B      0     2
# 1407    2016   WO     112  20160821      SS          0     B      0     0
# 1408    2016   WO     113  20160824      HH          0     T      0     0
#
#       INN2  ...  IB_B  HP_B  KK_B  GD_B  ERR_B  LOB_B  P_HRA_RT_B  P_AB_CN_B  \
# ...

# %%
df_post = df.drop(del_list_pre)
df_post
# Out:
#       yearID T_ID  gameNO   GDAY_DS VS_T_ID  HEADER_NO TB_SC  CG_CK  HOLD  \
# 113     2016   HH     114  20160826      NC          0     B      0     1
# 114     2016   HH     115  20160827      SK          0     T      0     0
# 115     2016   HH     116  20160828      SK          0     T      0     0
# 116     2016   HH     117  20160830      OB          0     T      0     0
# 117     2016   HH     118  20160901      LG          0     B      0     0
# ...      ...  ...     ...       ...     ...        ...   ...    ...   ...
# 1435    2016   WO     140  20161002      HH          0     T      0     2
# 1436    2016   WO     141  20161004      NC          0     T      0     0
# 1437    2016   WO     142  20161005      NC          0     T      0     0
# 1438    2016   WO     143  20161007      LT          0     T      0     0
# 1439    2016   WO     144  20161009      LT          0     T      0     0
#
#       INN2  ...  IB_B  HP_B  KK_B  GD_B  ERR_B  LOB_B  P_HRA_RT_B  P_AB_CN_B  \
# ...

# %%
df_pre.to_csv('3. SplitedDatasets/2016_pre.csv', index = False, encoding = 'cp949')
df_post.to_csv('3. SplitedDatasets/2016_post.csv', index = False, encoding = 'cp949')
