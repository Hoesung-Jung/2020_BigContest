# %%
import pandas as pd
import numpy as np

# %%
data_team_pitcher = pd.read_csv('2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2016.csv', engine = 'python')
data_team_batter = pd.read_csv('2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2016.csv', engine = 'python')

# %%
df = data_team_batter
df
# Out:
#                G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  PA  AB  RBI  RUN  \
# 0     20160401HHLG0  20160401   LG      HH          0     B  47  42    4    5
# 1     20160401HHLG0  20160401   HH      LG          0     T  52  46    4    4
# 2     20160401HTNC0  20160401   NC      HT          0     B  36  30    5    5
# 3     20160401HTNC0  20160401   HT      NC          0     T  38  34    3    4
# 4     20160401KTSK0  20160401   SK      KT          0     B  36  36    4    4
# 5     20160401KTSK0  20160401   KT      SK          0     T  42  36    7    8
# 6     20160401LTWO0  20160401   WO      LT          0     B  36  30    1    1
# 7     20160401LTWO0  20160401   LT      WO          0     T  39  37    1    2
# 8     20160401OBSS0  20160401   SS      OB          0     B  35  32    1    1
# 9     20160401OBSS0  20160401   OB      SS          0     T  37  31    4    5
# 10    20160402HHLG0  20160402   LG      HH          0     B  49  40    8    8
# ...

# %%
type(df["GDAY_DS"][0])
# Out:
# numpy.int64

# %%
df.loc[df["GDAY_DS"] < 20160826] #2016년도의 113경기만큼을 분리
# Out:
#                G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  PA  AB  RBI  RUN  \
# 0     20160401HHLG0  20160401   LG      HH          0     B  47  42    4    5
# 1     20160401HHLG0  20160401   HH      LG          0     T  52  46    4    4
# 2     20160401HTNC0  20160401   NC      HT          0     B  36  30    5    5
# 3     20160401HTNC0  20160401   HT      NC          0     T  38  34    3    4
# 4     20160401KTSK0  20160401   SK      KT          0     B  36  36    4    4
# 5     20160401KTSK0  20160401   KT      SK          0     T  42  36    7    8
# 6     20160401LTWO0  20160401   WO      LT          0     B  36  30    1    1
# 7     20160401LTWO0  20160401   LT      WO          0     T  39  37    1    2
# 8     20160401OBSS0  20160401   SS      OB          0     B  35  32    1    1
# 9     20160401OBSS0  20160401   OB      SS          0     T  37  31    4    5
# 10    20160402HHLG0  20160402   LG      HH          0     B  49  40    8    8
# ...
