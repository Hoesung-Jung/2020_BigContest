# %%
import pandas as pd

# %%
df_raw = pd.read_csv("datasets/2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2016.csv")

# %%
df_raw
# Out:
#                G_ID   GDAY_DS T_ID VS_T_ID  HEADER_NO TB_SC  CG_CK WLS  HOLD  \
# 0     20160401HHLG0  20160401   LG      HH          0     B      0   W     0
# 1     20160401HHLG0  20160401   HH      LG          0     T      0   L     0
# 2     20160401HTNC0  20160401   NC      HT          0     B      0   W     0
# 3     20160401HTNC0  20160401   HT      NC          0     T      0   L     0
# 4     20160401KTSK0  20160401   SK      KT          0     B      0   L     0
# ...             ...       ...  ...     ...        ...   ...    ...  ..   ...
# 1435  20161008SSSK0  20161008   SS      SK          0     T      0   L     0
# 1436  20161009KTNC0  20161009   NC      KT          0     B      0   L     0
# 1437  20161009KTNC0  20161009   KT      NC          0     T      0   W     1
# 1438  20161009WOLT0  20161009   LT      WO          0     B      0   W     1
# 1439  20161009WOLT0  20161009   WO      LT          0     T      0   L     0
#
#       INN2  ...  KK  GD  WP  BK  ERR  R  ER  P_WHIP_RT  P2_WHIP_RT  CB_WHIP_RT
# 0       36  ...  10   1   0   0    0  4   4   0.642857    1.285714    2.400000
# 1       34  ...  11   0   1   0    0  5   4   1.500000    1.000000    0.750000
# 2       27  ...  10   1   2   0    0  4   4   1.333333    1.038462    2.142857
# 3       24  ...   9   1   0   0    0  5   5   0.500000    1.695652    1.875000
# 4       27  ...   7   0   0   0    0  8   8   1.000000    2.357143    2.250000
# ...    ...  ...  ..  ..  ..  ..  ... ..  ..        ...         ...         ...
# 1435    24  ...   9   1   0   0    0  7   6   1.500000    2.538462    1.666667
# 1436    27  ...   7   0   2   1    0  7   7   0.900000    2.217391    1.500000
# 1437    27  ...  13   0   0   0    1  4   3   0.562500    1.428571    1.090909
# 1438    27  ...   6   1   1   0    0  5   5   1.500000    1.500000    1.000000
# 1439    24  ...   4   2   1   0    0  8   4   2.250000    1.666667    3.000000
#
# [1440 rows x 34 columns]

# %%
    def col_name_kr(df):
        df.rename(columns={'G_ID':'게임키'}, inplace =True)
        df.rename(columns={'GDAY_DS':'일자'}, inplace =True)
        df.rename(columns={'T_ID':'팀코드'}, inplace =True)
        df.rename(columns={'VS_T_ID':'상대팀코드'}, inplace =True)
        df.rename(columns={'HEADER_NO':'더블헤더코드'}, inplace =True)
        df.rename(columns={'TB_SC' :'초말'}, inplace =True)
        df.rename(columns={'CG_CK':'완투'}, inplace =True)
        df.rename(columns={'WLS':'결과'}, inplace =True)
        df.rename(columns={'HOLD':'홀드'}, inplace =True)
        df.rename(columns={'INN2':'이닝'}, inplace =True)
        df.rename(columns={'BF':'투구수'}, inplace =True)
        df.rename(columns={'PA':'타자'}, inplace =True)
        df.rename(columns={'AB':'타수'}, inplace =True)
        df.rename(columns={'HIT':'안타'}, inplace =True)
        df.rename(columns={'H2':'2루타'}, inplace =True)
        df.rename(columns={'H3':'3루타'}, inplace =True)
        df.rename(columns={'HR' :'홈런'}, inplace =True)
        df.rename(columns={'SB':'도루'}, inplace =True)
        df.rename(columns={'CS':'도루실패'}, inplace =True)
        df.rename(columns={'SH':'희타'}, inplace =True)
        df.rename(columns={'SF':'희비'}, inplace =True)
        df.rename(columns={'BB':'4구'}, inplace =True)
        df.rename(columns={'IB':'고4'}, inplace =True)
        df.rename(columns={'HP':'사구'}, inplace =True)
        df.rename(columns={'KK':'삼진'}, inplace =True)
        df.rename(columns={'GD':'병살타'}, inplace =True)
        df.rename(columns={'WP':'폭투'}, inplace =True)
        df.rename(columns={'BK' :'보크'}, inplace =True)
        df.rename(columns={'ERR':'실책'}, inplace =True)
        df.rename(columns={'R':'실점'}, inplace =True)
        df.rename(columns={'ER':'자책점'}, inplace =True)
        df.rename(columns={'P_WHIP_RT':'득점권WHIP'}, inplace =True)
        df.rename(columns={'P2_WHIP_RT':'2점차이하WHIP'}, inplace =True)
        df.rename(columns={'CB_WHIP_RT':'345번타자WHIP'}, inplace =True)

# %%
col_name_kr(df_raw)

# %%
df_raw
# Out:
#                 게임키        일자 팀코드 상대팀코드  더블헤더코드 초말  완투 결과  홀드  이닝  ...  삼진  \
# 0     20160401HHLG0  20160401  LG    HH       0  B   0  W   0  36  ...  10
# 1     20160401HHLG0  20160401  HH    LG       0  T   0  L   0  34  ...  11
# 2     20160401HTNC0  20160401  NC    HT       0  B   0  W   0  27  ...  10
# 3     20160401HTNC0  20160401  HT    NC       0  T   0  L   0  24  ...   9
# 4     20160401KTSK0  20160401  SK    KT       0  B   0  L   0  27  ...   7
# ...             ...       ...  ..   ...     ... ..  .. ..  ..  ..  ...  ..
# 1435  20161008SSSK0  20161008  SS    SK       0  T   0  L   0  24  ...   9
# 1436  20161009KTNC0  20161009  NC    KT       0  B   0  L   0  27  ...   7
# 1437  20161009KTNC0  20161009  KT    NC       0  T   0  W   1  27  ...  13
# 1438  20161009WOLT0  20161009  LT    WO       0  B   0  W   1  27  ...   6
# 1439  20161009WOLT0  20161009  WO    LT       0  T   0  L   0  24  ...   4
#
#       병살타  폭투  보크  실책  실점  자책점   득점권WHIP  2점차이하WHIP  345번타자WHIP
# 0       1   0   0   0   4    4  0.642857   1.285714    2.400000
# 1       0   1   0   0   5    4  1.500000   1.000000    0.750000
# 2       1   2   0   0   4    4  1.333333   1.038462    2.142857
# 3       1   0   0   0   5    5  0.500000   1.695652    1.875000
# 4       0   0   0   0   8    8  1.000000   2.357143    2.250000
# ...   ...  ..  ..  ..  ..  ...       ...        ...         ...
# 1435    1   0   0   0   7    6  1.500000   2.538462    1.666667
# 1436    0   2   1   0   7    7  0.900000   2.217391    1.500000
# 1437    0   0   0   1   4    3  0.562500   1.428571    1.090909
# 1438    1   1   0   0   5    5  1.500000   1.500000    1.000000
# 1439    2   1   0   0   8    4  2.250000   1.666667    3.000000
#
# [1440 rows x 34 columns]

# %%
df_raw['일자']
# Out:
# 0       20160401
# 1       20160401
# 2       20160401
# 3       20160401
# 4       20160401
#           ...
# 1435    20161008
# 1436    20161009
# 1437    20161009
# 1438    20161009
# 1439    20161009
# Name: 일자, Length: 1440, dtype: int64

# %% [markdown]
# 방어율데이터 생성

# %%
def avg(df):
    df['방어율'] = df['자책점']/(df['이닝'])*27

# %%
df_mod = df_raw.loc[:,'타자':]
df_mod
# Out:
#       타자  타수  안타  2루타  3루타  홈런  도루  도루실패  희타  희비  ...  삼진  병살타  폭투  보크  실책  \
# 0     52  46  13    2    0   0   0     0   3   0  ...  10    1   0   0   0
# 1     47  42   9    2    0   1   2     1   1   0  ...  11    0   1   0   0
# 2     38  34   8    3    0   1   0     0   0   0  ...  10    1   2   0   0
# 3     36  30   9    2    0   2   0     0   1   0  ...   9    1   0   0   0
# 4     42  36  11    0    0   2   2     1   0   1  ...   7    0   0   0   0
# ...   ..  ..  ..  ...  ...  ..  ..   ...  ..  ..  ...  ..  ...  ..  ..  ..
# 1435  40  37  12    0    1   3   0     0   0   0  ...   9    1   0   0   0
# 1436  43  38  14    3    0   0   1     0   1   1  ...   7    0   2   1   0
# 1437  41  39  12    4    0   0   4     1   0   0  ...  13    0   0   0   1
# 1438  38  33  10    0    0   0   0     1   0   2  ...   6    1   1   0   0
# 1439  38  36  11    2    0   2   1     0   0   0  ...   4    2   1   0   0
#
#       실점  자책점   득점권WHIP  2점차이하WHIP  345번타자WHIP
# 0      4    4  0.642857   1.285714    2.400000
# 1      5    4  1.500000   1.000000    0.750000
# 2      4    4  1.333333   1.038462    2.142857
# 3      5    5  0.500000   1.695652    1.875000
# 4      8    8  1.000000   2.357143    2.250000
# ...   ..  ...       ...        ...         ...
# 1435   7    6  1.500000   2.538462    1.666667
# 1436   7    7  0.900000   2.217391    1.500000
# 1437   4    3  0.562500   1.428571    1.090909
# 1438   5    5  1.500000   1.500000    1.000000
# 1439   8    4  2.250000   1.666667    3.000000
#
# [1440 rows x 23 columns]

# %% [markdown]
# 시계열 데이터를 위해 누적데이터를 만들어낸다.

# %%
def accum_bat(df):
    df_mod = df.loc[:,'홀드':]
    df_accum = []
    col = df.columns[8:]
    for i in range(len(df_mod)):
        if i == 0:
            df_accum.append(df_mod.values[i])
        else:
            df_accum.append(df_accum[i-1] + df_mod.values[i])
    df_accum = pd.DataFrame(df_accum, columns=col)
    
    #일자 컬럼 추가
    ser_date = pd.to_datetime(df['일자'], format='%Y%m%d',errors='ignore')
    ser_date_mod = ser_date.reset_index()
    df_accum['일자']=ser_date_mod['일자']
    

    return df_accum

# %% [markdown]
# 이제 예열은 끝났다. 팀별 코드를 만들고 위 함수를 수정해보자.
#
# - accum_bat함수 수정:  1.return의 dataframe에 date 컬럼을 추가하였다. 2. 득점권타율 column 삭제.
# - accum_bat함수 수정:  3. datetime이 NaT로 사라지는 현상발견: 이는 to_datetime에 시리즈를 넣었기에 row값이 저장된 상태로 들어갔다. 다시 인덱싱 필요함.

# %%
def team_sep(df,team):
    df_new =df[df['팀코드']==team]
    return df_new

# %%
df_LG = team_sep(df_raw,'LG')
df_HH = team_sep(df_raw,'HH')
df_NC = team_sep(df_raw,'NC')
df_HT = team_sep(df_raw,'HT')
df_SK = team_sep(df_raw,'SK')
df_KT = team_sep(df_raw,'KT')
df_WO = team_sep(df_raw,'WO')
df_LT = team_sep(df_raw,'LT')
df_SS = team_sep(df_raw,'SS')
df_OB = team_sep(df_raw,'OB')

'''
0    LG
1    HH
2    NC
3    HT
4    SK
5    KT
6    WO
7    LT
8    SS
9    OB
'''
# Out:
# '\n0    LG\n1    HH\n2    NC\n3    HT\n4    SK\n5    KT\n6    WO\n7    LT\n8    SS\n9    OB\n'

# %%
df_LG
# Out:
#                 게임키        일자 팀코드 상대팀코드  더블헤더코드 초말  완투 결과  홀드  이닝  ...  삼진  \
# 0     20160401HHLG0  20160401  LG    HH       0  B   0  W   0  36  ...  10
# 10    20160402HHLG0  20160402  LG    HH       0  B   0  W   2  33  ...   9
# 25    20160405LGHT0  20160405  LG    HT       0  T   0  L   0  24  ...  10
# 43    20160407LGHT0  20160407  LG    HT       0  T   0  W   2  27  ...   6
# 57    20160408LGSK0  20160408  LG    SK       0  T   0  L   0  29  ...   4
# ...             ...       ...  ..   ...     ... ..  .. ..  ..  ..  ...  ..
# 1394  20161001SKLG0  20161001  LG    SK       0  B   0  L   0  27  ...   9
# 1407  20161003LGSS0  20161003  LG    SS       0  T   0  W   2  27  ...   9
# 1409  20161004LGSS0  20161004  LG    SS       0  T   0  L   0  24  ...   3
# 1421  20161006LGLT0  20161006  LG    LT       0  T   0  W   3  27  ...   9
# 1432  20161008OBLG0  20161008  LG    OB       0  B   0  L   0  27  ...   6
#
#       병살타  폭투  보크  실책  실점  자책점   득점권WHIP  2점차이하WHIP  345번타자WHIP
# 0       1   0   0   0   4    4  0.642857   1.285714    2.400000
# 10      0   0   0   0   7    7  1.909091   1.272727    1.500000
# 25      2   1   0   0   4    2  2.000000   1.588235    0.600000
# 43      1   1   0   0   4    4  3.000000   1.071429    0.666667
# 57      0   1   0   0   3    1  0.000000   1.241379    1.090909
# ...   ...  ..  ..  ..  ..  ...       ...        ...         ...
# 1394    1   1   0   0   5    5  0.428571   2.100000    0.750000
# 1407    0   0   0   0   3    3  1.000000   1.125000    2.142857
# 1409    1   1   0   0   5    5  0.545455   1.800000    1.875000
# 1421    2   0   0   0   1    1  0.900000   1.500000    1.333333
# 1432    1   1   0   1  11   10  2.181818   3.000000    3.857143
#
# [144 rows x 34 columns]

# %%
LG_accum = accum_bat(df_LG)
HH_accum = accum_bat(df_HH)
NC_accum = accum_bat(df_NC)
HT_accum = accum_bat(df_HT)
SK_accum = accum_bat(df_SK)
KT_accum = accum_bat(df_KT)
WO_accum = accum_bat(df_WO)
LT_accum = accum_bat(df_LT)
SS_accum = accum_bat(df_SS)
OB_accum = accum_bat(df_OB)

# %%
avg(LG_accum)
avg(HH_accum)
avg(NC_accum)
avg(HT_accum)
avg(SK_accum)
avg(KT_accum)
avg(WO_accum)
avg(LT_accum)
avg(SS_accum)
avg(OB_accum)

# %%
LG_accum
# Out:
#        홀드      이닝      투구수      타자      타수      안타    2루타   3루타     홈런    도루  \
# 0     0.0    36.0    184.0    52.0    46.0    13.0    2.0   0.0    0.0   0.0
# 1     2.0    69.0    360.0   102.0    89.0    26.0    6.0   0.0    0.0   0.0
# 2     2.0    93.0    483.0   133.0   117.0    32.0    7.0   0.0    1.0   0.0
# 3     4.0   120.0    620.0   170.0   151.0    41.0   12.0   0.0    1.0   1.0
# 4     4.0   149.0    762.0   211.0   187.0    49.0   12.0   0.0    1.0   1.0
# ..    ...     ...      ...     ...     ...     ...    ...   ...    ...   ...
# 139  70.0  3758.0  21437.0  5625.0  4880.0  1387.0  236.0  23.0  119.0  85.0
# 140  72.0  3785.0  21619.0  5662.0  4912.0  1393.0  238.0  23.0  119.0  85.0
# 141  72.0  3809.0  21765.0  5699.0  4941.0  1403.0  239.0  23.0  120.0  85.0
# 142  75.0  3836.0  21921.0  5735.0  4972.0  1410.0  240.0  23.0  120.0  85.0
# 143  75.0  3863.0  22100.0  5782.0  5013.0  1426.0  243.0  23.0  122.0  85.0
#
#      ...    폭투   보크    실책     실점    자책점     득점권WHIP   2점차이하WHIP  345번타자WHIP  \
# 0    ...   0.0  0.0   0.0    4.0    4.0    0.642857    1.285714    2.400000
# 1    ...   0.0  0.0   0.0   11.0   11.0    2.551948    2.558442    3.900000
# 2    ...   1.0  0.0   0.0   15.0   13.0    4.551948    4.146677    4.500000
# 3    ...   2.0  0.0   0.0   19.0   17.0    7.551948    5.218105    5.166667
# 4    ...   3.0  0.0   0.0   22.0   18.0    7.551948    6.459485    6.257576
# ..   ...   ...  ...   ...    ...    ...         ...         ...         ...
# 139  ...  82.0  1.0  15.0  787.0  702.0  257.863178  278.029613  255.609732
# 140  ...  82.0  1.0  15.0  790.0  705.0  258.863178  279.154613  257.752589
# 141  ...  83.0  1.0  15.0  795.0  710.0  259.408632  280.954613  259.627589
# 142  ...  83.0  1.0  15.0  796.0  711.0  260.308632  282.454613  260.960922
# 143  ...  84.0  1.0  16.0  807.0  721.0  262.490450  285.454613  264.818065
#
#             일자       방어율
# 0   2016-04-01  3.000000
# 1   2016-04-02  4.304348
# 2   2016-04-05  3.774194
# 3   2016-04-07  3.825000
# 4   2016-04-08  3.261745
# ..         ...       ...
# 139 2016-10-01  5.043640
# 140 2016-10-03  5.029062
# 141 2016-10-04  5.032817
# 142 2016-10-06  5.004432
# 143 2016-10-08  5.039348
#
# [144 rows x 28 columns]

# %% [markdown]
# 혹시 일자랑 타율만 가지고 RNN돌려도 될까?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16,9))
sns.lineplot( x=LG_accum['일자'], y=LG_accum['방어율'])
plt.xlabel('time')
plt.ylabel('AVG')
plt.show()

# %% [markdown]
# 무엇을 피쳐로 사용할까? 아마 경기당 기록으로 바꿔야 좋을것 같다.

# %%
def per_fit(df):
    #타자부터 득점권안타까지 경기당 기록으로 change
    for i in range(len(df)):
        df.loc[i,:'득점권안타'] = df.loc[i,:'득점권안타']/(i+1)

# %% [markdown]
# scaling 필요

# %%
def scale(df):
    from sklearn.preprocessing import MinMaxScaler
    scale_cols = list(df.columns[:-3])
    scaler = MinMaxScaler()
    scaled_df = scaler.fit_transform(df[scale_cols])
    df[scale_cols] = scaled_df
    #일자, 타율, 득점권 타율 제외

# %% [markdown]
# 0    LG
# 1    HH
# 2    NC
# 3    HT
# 4    SK
# 5    KT
# 6    WO
# 7    LT
# 8    SS
# 9    OB

# %%
# per_fit(LG_accum)
# per_fit(HH_accum)
# per_fit(NC_accum)
# per_fit(HT_accum)
# per_fit(SK_accum)
# per_fit(KT_accum)
# per_fit(WO_accum)
# per_fit(LT_accum)
# per_fit(SS_accum)
# per_fit(OB_accum)

scale(LG_accum)
scale(HH_accum)
scale(NC_accum)
scale(HT_accum)
scale(SK_accum)
scale(KT_accum)
scale(WO_accum)
scale(LT_accum)
scale(SS_accum)
scale(OB_accum)

# %%
LG_accum
# Out:
#            홀드        이닝       투구수        타자        타수        안타       2루타  \
# 0    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    0.026667  0.008623  0.008031  0.008726  0.008657  0.009200  0.016598
# 2    0.026667  0.014894  0.013643  0.014136  0.014294  0.013447  0.020747
# 3    0.053333  0.021949  0.019894  0.020593  0.021140  0.019816  0.041494
# 4    0.053333  0.029527  0.026373  0.027749  0.028387  0.025478  0.041494
# ..        ...       ...       ...       ...       ...       ...       ...
# 139  0.933333  0.972563  0.969748  0.972600  0.973223  0.972399  0.970954
# 140  0.960000  0.979619  0.978053  0.979058  0.979666  0.976645  0.979253
# 141  0.960000  0.985890  0.984714  0.985515  0.985504  0.983723  0.983402
# 142  1.000000  0.992945  0.991832  0.991798  0.991746  0.988677  0.987552
# 143  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
#
#      3루타        홈런        도루  ...        폭투   보크      실책        실점       자책점  \
# 0    0.0  0.000000  0.000000  ...  0.000000  0.0  0.0000  0.000000  0.000000
# 1    0.0  0.000000  0.000000  ...  0.000000  0.0  0.0000  0.008717  0.009763
# 2    0.0  0.008197  0.000000  ...  0.011905  0.0  0.0000  0.013699  0.012552
# 3    0.0  0.008197  0.011765  ...  0.023810  0.0  0.0000  0.018680  0.018131
# 4    0.0  0.008197  0.011765  ...  0.035714  0.0  0.0000  0.022416  0.019526
# ..   ...       ...       ...  ...       ...  ...     ...       ...       ...
# 139  1.0  0.975410  1.000000  ...  0.976190  1.0  0.9375  0.975093  0.973501
# 140  1.0  0.975410  1.000000  ...  0.976190  1.0  0.9375  0.978829  0.977685
# 141  1.0  0.983607  1.000000  ...  0.988095  1.0  0.9375  0.985056  0.984658
# 142  1.0  0.983607  1.000000  ...  0.988095  1.0  0.9375  0.986301  0.986053
# 143  1.0  1.000000  1.000000  ...  1.000000  1.0  1.0000  1.000000  1.000000
#
#       득점권WHIP  2점차이하WHIP  345번타자WHIP         일자       방어율
# 0    0.000000   0.000000    2.400000 2016-04-01  3.000000
# 1    0.007291   0.004479    3.900000 2016-04-02  4.304348
# 2    0.014929   0.010068    4.500000 2016-04-05  3.774194
# 3    0.026386   0.013838    5.166667 2016-04-07  3.825000
# 4    0.026386   0.018207    6.257576 2016-04-08  3.261745
# ..        ...        ...         ...        ...       ...
# 139  0.982328   0.973871  255.609732 2016-10-01  5.043640
# 140  0.986147   0.977830  257.752589 2016-10-03  5.029062
# 141  0.988230   0.984164  259.627589 2016-10-04  5.032817
# 142  0.991668   0.989443  260.960922 2016-10-06  5.004432
# 143  1.000000   1.000000  264.818065 2016-10-08  5.039348
#
# [144 rows x 28 columns]

# %% [markdown]
# 전체 데이터로 병합

# %%
df = pd.concat([LG_accum, HH_accum, NC_accum, HT_accum, SK_accum, KT_accum, WO_accum, LT_accum, SS_accum, OB_accum], ignore_index=True)

# %%
df
# Out:
#             홀드        이닝       투구수        타자        타수        안타       2루타  \
# 0     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     0.026667  0.008623  0.008031  0.008726  0.008657  0.009200  0.016598
# 2     0.026667  0.014894  0.013643  0.014136  0.014294  0.013447  0.020747
# 3     0.053333  0.021949  0.019894  0.020593  0.021140  0.019816  0.041494
# 4     0.053333  0.029527  0.026373  0.027749  0.028387  0.025478  0.041494
# ...        ...       ...       ...       ...       ...       ...       ...
# 1435  1.000000  0.971064  0.969194  0.967633  0.968421  0.961511  0.959350
# 1436  1.000000  0.978102  0.976510  0.976169  0.976923  0.972404  0.971545
# 1437  1.000000  0.985141  0.984824  0.985239  0.985425  0.986928  0.987805
# 1438  1.000000  0.992961  0.993866  0.993953  0.994130  0.997821  0.995935
# 1439  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
#
#            3루타        홈런        도루  ...        폭투    보크   실책        실점  \
# 0     0.000000  0.000000  0.000000  ...  0.000000  0.00  0.0  0.000000
# 1     0.000000  0.000000  0.000000  ...  0.000000  0.00  0.0  0.008717
# 2     0.000000  0.008197  0.000000  ...  0.011905  0.00  0.0  0.013699
# 3     0.000000  0.008197  0.011765  ...  0.023810  0.00  0.0  0.018680
# 4     0.000000  0.008197  0.011765  ...  0.035714  0.00  0.0  0.022416
# ...        ...       ...       ...  ...       ...   ...  ...       ...
# 1435  0.966667  0.977941  0.952381  ...  1.000000  0.75  1.0  0.958884
# 1436  0.966667  0.992647  0.952381  ...  1.000000  0.75  1.0  0.972100
# 1437  1.000000  1.000000  0.952381  ...  1.000000  0.75  1.0  0.991189
# 1438  1.000000  1.000000  1.000000  ...  1.000000  1.00  1.0  0.998532
# 1439  1.000000  1.000000  1.000000  ...  1.000000  1.00  1.0  1.000000
#
#            자책점   득점권WHIP  2점차이하WHIP  345번타자WHIP         일자       방어율
# 0     0.000000  0.000000   0.000000    2.400000 2016-04-01  3.000000
# 1     0.009763  0.007291   0.004479    3.900000 2016-04-02  4.304348
# 2     0.012552  0.014929   0.010068    4.500000 2016-04-05  3.774194
# 3     0.018131  0.026386   0.013838    5.166667 2016-04-07  3.825000
# 4     0.019526  0.026386   0.018207    6.257576 2016-04-08  3.261745
# ...        ...       ...        ...         ...        ...       ...
# 1435  0.957480  0.968327   0.965514  253.630461 2016-09-28  4.382463
# 1436  0.971654  0.977782   0.977845  255.266825 2016-09-29  4.415454
# 1437  0.992126  0.983297   0.991409  259.981111 2016-10-03  4.476353
# 1438  1.000000  0.994327   1.000000  261.481111 2016-10-04  4.476538
# 1439  1.000000  1.000000   1.000000  262.081111 2016-10-08  4.445250
#
# [1440 rows x 28 columns]

# %% [markdown]
# 타율을 label로 설정

# %%
TEST_SIZE = 144

# %%
train = df[:-TEST_SIZE]
test = df[-TEST_SIZE:]

# %%
# 20일(window_size=20) 데이터를 묶어서 처리하는 함수
def make_dateset(data, label, window_size=10):
    import numpy as np
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
feature_cols = df.columns[:-3]
label_cols = ['방어율']

# %%
train_feature, train_label = make_dateset(train[feature_cols], train[label_cols])
test_feature, test_label = make_dateset(test[feature_cols], test[label_cols])

# %%
test_feature, test_label = make_dateset(test[feature_cols], test[label_cols])

# %%
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(
    train_feature, train_label, test_size=0.1)

# %%
x_train.shape, x_valid.shape
# Out:
# ((1157, 10, 25), (129, 10, 25))

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import LSTM
# Out:
# C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\User\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
model = Sequential()

# %%
model.add(LSTM(16, activation='relu',
              input_shape=(train_feature.shape[1], train_feature.shape[2])))
model.add(Dense(1))
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10)

# %%
hist = model.fit(x_train, y_train, epochs=200, batch_size=16,
                validation_data=(x_valid, y_valid))
# Out:
# Train on 1157 samples, validate on 129 samples
# WARNING:tensorflow:From C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/200
# 1157/1157 [==============================] - 1s 622us/sample - loss: 11.5996 - mean_absolute_error: 2.9327 - val_loss: 2.9394 - val_mean_absolute_error: 1.1874
# Epoch 2/200
# 1157/1157 [==============================] - 0s 291us/sample - loss: 1.8525 - mean_absolute_error: 0.9419 - val_loss: 1.1919 - val_mean_absolute_error: 0.7240
# Epoch 3/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.6502 - mean_absolute_error: 0.6271 - val_loss: 0.8022 - val_mean_absolute_error: 0.6121
# Epoch 4/200
# 1157/1157 [==============================] - 0s 275us/sample - loss: 0.4470 - mean_absolute_error: 0.5400 - val_loss: 0.8748 - val_mean_absolute_error: 0.6089
# Epoch 5/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.3751 - mean_absolute_error: 0.4951 - val_loss: 0.6896 - val_mean_absolute_error: 0.5078
# Epoch 6/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.3320 - mean_absolute_error: 0.4556 - val_loss: 0.6582 - val_mean_absolute_error: 0.4983
# Epoch 7/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.3097 - mean_absolute_error: 0.4403 - val_loss: 0.6788 - val_mean_absolute_error: 0.4988
# Epoch 8/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.3183 - mean_absolute_error: 0.4451 - val_loss: 0.6403 - val_mean_absolute_error: 0.4660
# Epoch 9/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.2695 - mean_absolute_error: 0.4055 - val_loss: 0.5822 - val_mean_absolute_error: 0.4391
# Epoch 10/200
# 1157/1157 [==============================] - 0s 276us/sample - loss: 0.2526 - mean_absolute_error: 0.3898 - val_loss: 0.5756 - val_mean_absolute_error: 0.4331
# Epoch 11/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.2483 - mean_absolute_error: 0.3829 - val_loss: 0.6570 - val_mean_absolute_error: 0.4767
# Epoch 12/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.2292 - mean_absolute_error: 0.3656 - val_loss: 0.5766 - val_mean_absolute_error: 0.4516
# Epoch 13/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.2096 - mean_absolute_error: 0.3466 - val_loss: 0.5601 - val_mean_absolute_error: 0.4065
# Epoch 14/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.2060 - mean_absolute_error: 0.3451 - val_loss: 0.5242 - val_mean_absolute_error: 0.3852
# Epoch 15/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.2068 - mean_absolute_error: 0.3476 - val_loss: 0.6072 - val_mean_absolute_error: 0.4963
# Epoch 16/200
# 1157/1157 [==============================] - 0s 273us/sample - loss: 0.2118 - mean_absolute_error: 0.3526 - val_loss: 0.5525 - val_mean_absolute_error: 0.4259
# Epoch 17/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1796 - mean_absolute_error: 0.3178 - val_loss: 0.5308 - val_mean_absolute_error: 0.3959
# Epoch 18/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.1694 - mean_absolute_error: 0.3050 - val_loss: 0.5639 - val_mean_absolute_error: 0.4063
# Epoch 19/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.1873 - mean_absolute_error: 0.3237 - val_loss: 0.5077 - val_mean_absolute_error: 0.3731
# Epoch 20/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1716 - mean_absolute_error: 0.3106 - val_loss: 0.5189 - val_mean_absolute_error: 0.3715
# Epoch 21/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.1984 - mean_absolute_error: 0.3375 - val_loss: 0.5126 - val_mean_absolute_error: 0.3638
# Epoch 22/200
# 1157/1157 [==============================] - 0s 271us/sample - loss: 0.1585 - mean_absolute_error: 0.2959 - val_loss: 0.5355 - val_mean_absolute_error: 0.3886
# Epoch 23/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1569 - mean_absolute_error: 0.2873 - val_loss: 0.5005 - val_mean_absolute_error: 0.3574
# Epoch 24/200
# 1157/1157 [==============================] - 0s 285us/sample - loss: 0.1587 - mean_absolute_error: 0.2965 - val_loss: 0.5202 - val_mean_absolute_error: 0.3855
# Epoch 25/200
# 1157/1157 [==============================] - 0s 285us/sample - loss: 0.1591 - mean_absolute_error: 0.2929 - val_loss: 0.4696 - val_mean_absolute_error: 0.3330
# Epoch 26/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.1521 - mean_absolute_error: 0.2850 - val_loss: 0.5582 - val_mean_absolute_error: 0.4067
# Epoch 27/200
# 1157/1157 [==============================] - 0s 285us/sample - loss: 0.1457 - mean_absolute_error: 0.2795 - val_loss: 0.5256 - val_mean_absolute_error: 0.3773
# Epoch 28/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1502 - mean_absolute_error: 0.2919 - val_loss: 0.4898 - val_mean_absolute_error: 0.3461
# Epoch 29/200
# 1157/1157 [==============================] - 0s 292us/sample - loss: 0.1458 - mean_absolute_error: 0.2797 - val_loss: 0.5296 - val_mean_absolute_error: 0.3944
# Epoch 30/200
# 1157/1157 [==============================] - 0s 286us/sample - loss: 0.1530 - mean_absolute_error: 0.2907 - val_loss: 0.5326 - val_mean_absolute_error: 0.4650
# Epoch 31/200
# 1157/1157 [==============================] - 0s 286us/sample - loss: 0.1534 - mean_absolute_error: 0.2858 - val_loss: 0.4755 - val_mean_absolute_error: 0.3506
# Epoch 32/200
# 1157/1157 [==============================] - 0s 286us/sample - loss: 0.1458 - mean_absolute_error: 0.2783 - val_loss: 0.4687 - val_mean_absolute_error: 0.3271
# Epoch 33/200
# 1157/1157 [==============================] - 0s 287us/sample - loss: 0.1331 - mean_absolute_error: 0.2625 - val_loss: 0.5303 - val_mean_absolute_error: 0.4487
# Epoch 34/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.1484 - mean_absolute_error: 0.2870 - val_loss: 0.4736 - val_mean_absolute_error: 0.3236
# Epoch 35/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.1321 - mean_absolute_error: 0.2589 - val_loss: 0.4807 - val_mean_absolute_error: 0.3207
# Epoch 36/200
# 1157/1157 [==============================] - 0s 288us/sample - loss: 0.1259 - mean_absolute_error: 0.2470 - val_loss: 0.4943 - val_mean_absolute_error: 0.3324
# Epoch 37/200
# 1157/1157 [==============================] - 0s 289us/sample - loss: 0.1503 - mean_absolute_error: 0.2869 - val_loss: 0.5559 - val_mean_absolute_error: 0.4185
# Epoch 38/200
# 1157/1157 [==============================] - 0s 285us/sample - loss: 0.1343 - mean_absolute_error: 0.2646 - val_loss: 0.4646 - val_mean_absolute_error: 0.3107
# Epoch 39/200
# 1157/1157 [==============================] - 0s 288us/sample - loss: 0.1247 - mean_absolute_error: 0.2481 - val_loss: 0.4599 - val_mean_absolute_error: 0.3040
# Epoch 40/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.1266 - mean_absolute_error: 0.2506 - val_loss: 0.4538 - val_mean_absolute_error: 0.3310
# Epoch 41/200
# 1157/1157 [==============================] - 0s 285us/sample - loss: 0.1283 - mean_absolute_error: 0.2531 - val_loss: 0.6022 - val_mean_absolute_error: 0.4603
# Epoch 42/200
# 1157/1157 [==============================] - 0s 289us/sample - loss: 0.1540 - mean_absolute_error: 0.2832 - val_loss: 0.4800 - val_mean_absolute_error: 0.3194
# Epoch 43/200
# 1157/1157 [==============================] - 0s 286us/sample - loss: 0.1154 - mean_absolute_error: 0.2333 - val_loss: 0.4499 - val_mean_absolute_error: 0.3260
# Epoch 44/200
# 1157/1157 [==============================] - 0s 288us/sample - loss: 0.1200 - mean_absolute_error: 0.2347 - val_loss: 0.4661 - val_mean_absolute_error: 0.3134
# Epoch 45/200
# 1157/1157 [==============================] - 0s 290us/sample - loss: 0.1171 - mean_absolute_error: 0.2325 - val_loss: 0.4418 - val_mean_absolute_error: 0.2905
# Epoch 46/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1255 - mean_absolute_error: 0.2497 - val_loss: 0.4403 - val_mean_absolute_error: 0.2988
# Epoch 47/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1215 - mean_absolute_error: 0.2398 - val_loss: 0.4682 - val_mean_absolute_error: 0.3081
# Epoch 48/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.1270 - mean_absolute_error: 0.2483 - val_loss: 0.4540 - val_mean_absolute_error: 0.3411
# Epoch 49/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1113 - mean_absolute_error: 0.2263 - val_loss: 0.4379 - val_mean_absolute_error: 0.2843
# Epoch 50/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1188 - mean_absolute_error: 0.2342 - val_loss: 0.4955 - val_mean_absolute_error: 0.3329
# Epoch 51/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1221 - mean_absolute_error: 0.2414 - val_loss: 0.4418 - val_mean_absolute_error: 0.3145
# Epoch 52/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1168 - mean_absolute_error: 0.2330 - val_loss: 0.4632 - val_mean_absolute_error: 0.3659
# Epoch 53/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1248 - mean_absolute_error: 0.2430 - val_loss: 0.4261 - val_mean_absolute_error: 0.2775
# Epoch 54/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1133 - mean_absolute_error: 0.2270 - val_loss: 0.4878 - val_mean_absolute_error: 0.3163
# Epoch 55/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.1116 - mean_absolute_error: 0.2237 - val_loss: 0.4599 - val_mean_absolute_error: 0.3008
# Epoch 56/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1087 - mean_absolute_error: 0.2217 - val_loss: 0.4610 - val_mean_absolute_error: 0.3028
# Epoch 57/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.1235 - mean_absolute_error: 0.2478 - val_loss: 0.4553 - val_mean_absolute_error: 0.2926
# Epoch 58/200
# 1157/1157 [==============================] - 0s 277us/sample - loss: 0.1123 - mean_absolute_error: 0.2244 - val_loss: 0.4613 - val_mean_absolute_error: 0.2960
# Epoch 59/200
# 1157/1157 [==============================] - 0s 275us/sample - loss: 0.1167 - mean_absolute_error: 0.2257 - val_loss: 0.4808 - val_mean_absolute_error: 0.3935
# Epoch 60/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.1132 - mean_absolute_error: 0.2251 - val_loss: 0.4401 - val_mean_absolute_error: 0.2901
# Epoch 61/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.1271 - mean_absolute_error: 0.2493 - val_loss: 0.5170 - val_mean_absolute_error: 0.3618
# Epoch 62/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.1154 - mean_absolute_error: 0.2287 - val_loss: 0.4598 - val_mean_absolute_error: 0.3234
# Epoch 63/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.1081 - mean_absolute_error: 0.2209 - val_loss: 0.5745 - val_mean_absolute_error: 0.4244
# Epoch 64/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.1125 - mean_absolute_error: 0.2263 - val_loss: 0.4336 - val_mean_absolute_error: 0.2994
# Epoch 65/200
# 1157/1157 [==============================] - 0s 276us/sample - loss: 0.1094 - mean_absolute_error: 0.2269 - val_loss: 0.5778 - val_mean_absolute_error: 0.3910
# Epoch 66/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.1126 - mean_absolute_error: 0.2236 - val_loss: 0.4300 - val_mean_absolute_error: 0.2756
# Epoch 67/200
# 1157/1157 [==============================] - 0s 285us/sample - loss: 0.1032 - mean_absolute_error: 0.2189 - val_loss: 0.4484 - val_mean_absolute_error: 0.3279
# Epoch 68/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1289 - mean_absolute_error: 0.2561 - val_loss: 0.4524 - val_mean_absolute_error: 0.3179
# Epoch 69/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.1125 - mean_absolute_error: 0.2271 - val_loss: 0.4370 - val_mean_absolute_error: 0.2779
# Epoch 70/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.1211 - mean_absolute_error: 0.2427 - val_loss: 0.4274 - val_mean_absolute_error: 0.2711
# Epoch 71/200
# 1157/1157 [==============================] - 0s 276us/sample - loss: 0.1047 - mean_absolute_error: 0.2137 - val_loss: 0.5390 - val_mean_absolute_error: 0.3586
# Epoch 72/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.1083 - mean_absolute_error: 0.2219 - val_loss: 0.4495 - val_mean_absolute_error: 0.2765
# Epoch 73/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.1069 - mean_absolute_error: 0.2204 - val_loss: 0.4867 - val_mean_absolute_error: 0.3326
# Epoch 74/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.1138 - mean_absolute_error: 0.2269 - val_loss: 0.4375 - val_mean_absolute_error: 0.2704
# Epoch 75/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.1097 - mean_absolute_error: 0.2184 - val_loss: 0.4469 - val_mean_absolute_error: 0.2864
# Epoch 76/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.1022 - mean_absolute_error: 0.2094 - val_loss: 0.4433 - val_mean_absolute_error: 0.3190
# Epoch 77/200
# 1157/1157 [==============================] - 0s 276us/sample - loss: 0.0992 - mean_absolute_error: 0.1984 - val_loss: 0.4257 - val_mean_absolute_error: 0.3074
# Epoch 78/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.1105 - mean_absolute_error: 0.2212 - val_loss: 0.4420 - val_mean_absolute_error: 0.3000
# Epoch 79/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.0998 - mean_absolute_error: 0.2055 - val_loss: 0.4401 - val_mean_absolute_error: 0.2681
# Epoch 80/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.1010 - mean_absolute_error: 0.2079 - val_loss: 0.4257 - val_mean_absolute_error: 0.2624
# Epoch 81/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.1017 - mean_absolute_error: 0.2067 - val_loss: 0.4340 - val_mean_absolute_error: 0.2707
# Epoch 82/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.1027 - mean_absolute_error: 0.2113 - val_loss: 0.4245 - val_mean_absolute_error: 0.2868
# Epoch 83/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1066 - mean_absolute_error: 0.2200 - val_loss: 0.4704 - val_mean_absolute_error: 0.3102
# Epoch 84/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.1003 - mean_absolute_error: 0.2101 - val_loss: 0.4562 - val_mean_absolute_error: 0.2880
# Epoch 85/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.1136 - mean_absolute_error: 0.2299 - val_loss: 0.4311 - val_mean_absolute_error: 0.2713
# Epoch 86/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.1020 - mean_absolute_error: 0.2094 - val_loss: 0.4337 - val_mean_absolute_error: 0.2800
# Epoch 87/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.1225 - mean_absolute_error: 0.2451 - val_loss: 0.4620 - val_mean_absolute_error: 0.3486
# Epoch 88/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.1010 - mean_absolute_error: 0.2121 - val_loss: 0.4488 - val_mean_absolute_error: 0.2861
# Epoch 89/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1013 - mean_absolute_error: 0.2043 - val_loss: 0.4354 - val_mean_absolute_error: 0.3090
# Epoch 90/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0990 - mean_absolute_error: 0.2012 - val_loss: 0.4450 - val_mean_absolute_error: 0.2690
# Epoch 91/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.1002 - mean_absolute_error: 0.2043 - val_loss: 0.4580 - val_mean_absolute_error: 0.2833
# Epoch 92/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.0951 - mean_absolute_error: 0.1979 - val_loss: 0.4761 - val_mean_absolute_error: 0.3032
# Epoch 93/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.1068 - mean_absolute_error: 0.2154 - val_loss: 0.4273 - val_mean_absolute_error: 0.2580
# Epoch 94/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0928 - mean_absolute_error: 0.1976 - val_loss: 0.4272 - val_mean_absolute_error: 0.2655
# Epoch 95/200
# 1157/1157 [==============================] - 0s 275us/sample - loss: 0.0953 - mean_absolute_error: 0.1970 - val_loss: 0.4385 - val_mean_absolute_error: 0.2852
# Epoch 96/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.1005 - mean_absolute_error: 0.2066 - val_loss: 0.4245 - val_mean_absolute_error: 0.2490
# Epoch 97/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.1031 - mean_absolute_error: 0.2059 - val_loss: 0.4296 - val_mean_absolute_error: 0.2602
# Epoch 98/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.1013 - mean_absolute_error: 0.2091 - val_loss: 0.4550 - val_mean_absolute_error: 0.3181
# Epoch 99/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.1207 - mean_absolute_error: 0.2391 - val_loss: 0.4346 - val_mean_absolute_error: 0.2618
# Epoch 100/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.0899 - mean_absolute_error: 0.1878 - val_loss: 0.4472 - val_mean_absolute_error: 0.3300
# Epoch 101/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.1129 - mean_absolute_error: 0.2276 - val_loss: 0.4184 - val_mean_absolute_error: 0.2959
# Epoch 102/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.0957 - mean_absolute_error: 0.1946 - val_loss: 0.4216 - val_mean_absolute_error: 0.2589
# Epoch 103/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.1001 - mean_absolute_error: 0.2026 - val_loss: 0.4565 - val_mean_absolute_error: 0.3649
# Epoch 104/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.1028 - mean_absolute_error: 0.2157 - val_loss: 0.4493 - val_mean_absolute_error: 0.2899
# Epoch 105/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.0909 - mean_absolute_error: 0.1907 - val_loss: 0.4245 - val_mean_absolute_error: 0.2572
# Epoch 106/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.1049 - mean_absolute_error: 0.2101 - val_loss: 0.4335 - val_mean_absolute_error: 0.2992
# Epoch 107/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.0975 - mean_absolute_error: 0.1985 - val_loss: 0.4346 - val_mean_absolute_error: 0.2520
# Epoch 108/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.0941 - mean_absolute_error: 0.1931 - val_loss: 0.4279 - val_mean_absolute_error: 0.2557
# Epoch 109/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.0959 - mean_absolute_error: 0.1940 - val_loss: 0.4495 - val_mean_absolute_error: 0.2625
# Epoch 110/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.1028 - mean_absolute_error: 0.2059 - val_loss: 0.4163 - val_mean_absolute_error: 0.2445
# Epoch 111/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0924 - mean_absolute_error: 0.1940 - val_loss: 0.4193 - val_mean_absolute_error: 0.3022
# Epoch 112/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.0910 - mean_absolute_error: 0.1888 - val_loss: 0.4097 - val_mean_absolute_error: 0.2423
# Epoch 113/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.1026 - mean_absolute_error: 0.2052 - val_loss: 0.4811 - val_mean_absolute_error: 0.3178
# Epoch 114/200
# 1157/1157 [==============================] - 0s 275us/sample - loss: 0.0974 - mean_absolute_error: 0.2004 - val_loss: 0.4508 - val_mean_absolute_error: 0.2764
# Epoch 115/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.0949 - mean_absolute_error: 0.1969 - val_loss: 0.4614 - val_mean_absolute_error: 0.2830
# Epoch 116/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0998 - mean_absolute_error: 0.2093 - val_loss: 0.4498 - val_mean_absolute_error: 0.2690
# Epoch 117/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.1001 - mean_absolute_error: 0.2151 - val_loss: 0.4464 - val_mean_absolute_error: 0.3248
# Epoch 118/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0950 - mean_absolute_error: 0.1959 - val_loss: 0.5024 - val_mean_absolute_error: 0.3214
# Epoch 119/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.0943 - mean_absolute_error: 0.2005 - val_loss: 0.4414 - val_mean_absolute_error: 0.2688
# Epoch 120/200
# 1157/1157 [==============================] - 0s 276us/sample - loss: 0.1005 - mean_absolute_error: 0.2089 - val_loss: 0.4216 - val_mean_absolute_error: 0.2587
# Epoch 121/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0977 - mean_absolute_error: 0.1988 - val_loss: 0.4523 - val_mean_absolute_error: 0.2932
# Epoch 122/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0925 - mean_absolute_error: 0.1914 - val_loss: 0.4219 - val_mean_absolute_error: 0.2476
# Epoch 123/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.0929 - mean_absolute_error: 0.1921 - val_loss: 0.4104 - val_mean_absolute_error: 0.2467
# Epoch 124/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.0946 - mean_absolute_error: 0.1941 - val_loss: 0.4091 - val_mean_absolute_error: 0.2604
# Epoch 125/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.1030 - mean_absolute_error: 0.2073 - val_loss: 0.4970 - val_mean_absolute_error: 0.3261
# Epoch 126/200
# 1157/1157 [==============================] - 0s 276us/sample - loss: 0.0986 - mean_absolute_error: 0.2053 - val_loss: 0.4340 - val_mean_absolute_error: 0.2440
# Epoch 127/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0988 - mean_absolute_error: 0.2020 - val_loss: 0.4478 - val_mean_absolute_error: 0.2729
# Epoch 128/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0978 - mean_absolute_error: 0.1997 - val_loss: 0.4578 - val_mean_absolute_error: 0.2611
# Epoch 129/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0931 - mean_absolute_error: 0.1945 - val_loss: 0.4600 - val_mean_absolute_error: 0.2774
# Epoch 130/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.0965 - mean_absolute_error: 0.1975 - val_loss: 0.4312 - val_mean_absolute_error: 0.3135
# Epoch 131/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0907 - mean_absolute_error: 0.1889 - val_loss: 0.4392 - val_mean_absolute_error: 0.2497
# Epoch 132/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.0891 - mean_absolute_error: 0.1851 - val_loss: 0.4123 - val_mean_absolute_error: 0.2368
# Epoch 133/200
# 1157/1157 [==============================] - 0s 286us/sample - loss: 0.0913 - mean_absolute_error: 0.1935 - val_loss: 0.4642 - val_mean_absolute_error: 0.2922
# Epoch 134/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0983 - mean_absolute_error: 0.2063 - val_loss: 0.4341 - val_mean_absolute_error: 0.2916
# Epoch 135/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0874 - mean_absolute_error: 0.1811 - val_loss: 0.4291 - val_mean_absolute_error: 0.2339
# Epoch 136/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0949 - mean_absolute_error: 0.1910 - val_loss: 0.4441 - val_mean_absolute_error: 0.3301
# Epoch 137/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0932 - mean_absolute_error: 0.1874 - val_loss: 0.4260 - val_mean_absolute_error: 0.2750
# Epoch 138/200
# 1157/1157 [==============================] - 0s 277us/sample - loss: 0.0911 - mean_absolute_error: 0.1903 - val_loss: 0.4301 - val_mean_absolute_error: 0.2626
# Epoch 139/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0921 - mean_absolute_error: 0.1904 - val_loss: 0.4253 - val_mean_absolute_error: 0.2449
# Epoch 140/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.0885 - mean_absolute_error: 0.1853 - val_loss: 0.4340 - val_mean_absolute_error: 0.2499
# Epoch 141/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0998 - mean_absolute_error: 0.2046 - val_loss: 0.4166 - val_mean_absolute_error: 0.2508
# Epoch 142/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.0803 - mean_absolute_error: 0.1694 - val_loss: 0.4106 - val_mean_absolute_error: 0.2639
# Epoch 143/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.0993 - mean_absolute_error: 0.2002 - val_loss: 0.4478 - val_mean_absolute_error: 0.2568
# Epoch 144/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.0844 - mean_absolute_error: 0.1787 - val_loss: 0.4352 - val_mean_absolute_error: 0.2663
# Epoch 145/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.0900 - mean_absolute_error: 0.1867 - val_loss: 0.4254 - val_mean_absolute_error: 0.2671
# Epoch 146/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.0813 - mean_absolute_error: 0.1671 - val_loss: 0.4271 - val_mean_absolute_error: 0.2508
# Epoch 147/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.1008 - mean_absolute_error: 0.2044 - val_loss: 0.4484 - val_mean_absolute_error: 0.2612
# Epoch 148/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.0902 - mean_absolute_error: 0.1854 - val_loss: 0.4355 - val_mean_absolute_error: 0.2550
# Epoch 149/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0848 - mean_absolute_error: 0.1782 - val_loss: 0.4015 - val_mean_absolute_error: 0.2378
# Epoch 150/200
# 1157/1157 [==============================] - 0s 276us/sample - loss: 0.0875 - mean_absolute_error: 0.1859 - val_loss: 0.4195 - val_mean_absolute_error: 0.2653
# Epoch 151/200
# 1157/1157 [==============================] - 0s 276us/sample - loss: 0.0954 - mean_absolute_error: 0.1975 - val_loss: 0.4321 - val_mean_absolute_error: 0.2475
# Epoch 152/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0862 - mean_absolute_error: 0.1781 - val_loss: 0.4292 - val_mean_absolute_error: 0.2538
# Epoch 153/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.0842 - mean_absolute_error: 0.1801 - val_loss: 0.5235 - val_mean_absolute_error: 0.3372
# Epoch 154/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0858 - mean_absolute_error: 0.1761 - val_loss: 0.4127 - val_mean_absolute_error: 0.2582
# Epoch 155/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.0848 - mean_absolute_error: 0.1775 - val_loss: 0.4149 - val_mean_absolute_error: 0.2312
# Epoch 156/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.0940 - mean_absolute_error: 0.1922 - val_loss: 0.4491 - val_mean_absolute_error: 0.2512
# Epoch 157/200
# 1157/1157 [==============================] - 0s 275us/sample - loss: 0.1003 - mean_absolute_error: 0.2119 - val_loss: 0.4465 - val_mean_absolute_error: 0.2605
# Epoch 158/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0909 - mean_absolute_error: 0.1948 - val_loss: 0.4018 - val_mean_absolute_error: 0.2294
# Epoch 159/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0806 - mean_absolute_error: 0.1711 - val_loss: 0.4190 - val_mean_absolute_error: 0.2298
# Epoch 160/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.0881 - mean_absolute_error: 0.1831 - val_loss: 0.4264 - val_mean_absolute_error: 0.2290
# Epoch 161/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.0849 - mean_absolute_error: 0.1787 - val_loss: 0.4120 - val_mean_absolute_error: 0.2394
# Epoch 162/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0956 - mean_absolute_error: 0.2008 - val_loss: 0.4364 - val_mean_absolute_error: 0.2480
# Epoch 163/200
# 1157/1157 [==============================] - 0s 277us/sample - loss: 0.0812 - mean_absolute_error: 0.1716 - val_loss: 0.4088 - val_mean_absolute_error: 0.2936
# Epoch 164/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.0959 - mean_absolute_error: 0.2044 - val_loss: 0.4514 - val_mean_absolute_error: 0.2489
# Epoch 165/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.0893 - mean_absolute_error: 0.1851 - val_loss: 0.4115 - val_mean_absolute_error: 0.2375
# Epoch 166/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.0827 - mean_absolute_error: 0.1716 - val_loss: 0.4914 - val_mean_absolute_error: 0.3363
# Epoch 167/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.0858 - mean_absolute_error: 0.1833 - val_loss: 0.4239 - val_mean_absolute_error: 0.3013
# Epoch 168/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0882 - mean_absolute_error: 0.1827 - val_loss: 0.4273 - val_mean_absolute_error: 0.2370
# Epoch 169/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.0838 - mean_absolute_error: 0.1775 - val_loss: 0.4030 - val_mean_absolute_error: 0.2207
# Epoch 170/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.0826 - mean_absolute_error: 0.1745 - val_loss: 0.4258 - val_mean_absolute_error: 0.2657
# Epoch 171/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.0830 - mean_absolute_error: 0.1790 - val_loss: 0.4634 - val_mean_absolute_error: 0.2685
# Epoch 172/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.0810 - mean_absolute_error: 0.1684 - val_loss: 0.4070 - val_mean_absolute_error: 0.2463
# Epoch 173/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0846 - mean_absolute_error: 0.1823 - val_loss: 0.4085 - val_mean_absolute_error: 0.2363
# Epoch 174/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0846 - mean_absolute_error: 0.1782 - val_loss: 0.4341 - val_mean_absolute_error: 0.2576
# Epoch 175/200
# 1157/1157 [==============================] - 0s 276us/sample - loss: 0.0778 - mean_absolute_error: 0.1658 - val_loss: 0.4133 - val_mean_absolute_error: 0.2282
# Epoch 176/200
# 1157/1157 [==============================] - 0s 282us/sample - loss: 0.0834 - mean_absolute_error: 0.1840 - val_loss: 0.4127 - val_mean_absolute_error: 0.2576
# Epoch 177/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.0933 - mean_absolute_error: 0.1930 - val_loss: 0.4101 - val_mean_absolute_error: 0.2801
# Epoch 178/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.0886 - mean_absolute_error: 0.1882 - val_loss: 0.4148 - val_mean_absolute_error: 0.2324
# Epoch 179/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.0836 - mean_absolute_error: 0.1762 - val_loss: 0.4294 - val_mean_absolute_error: 0.2384
# Epoch 180/200
# 1157/1157 [==============================] - 0s 287us/sample - loss: 0.0822 - mean_absolute_error: 0.1732 - val_loss: 0.4044 - val_mean_absolute_error: 0.2263
# Epoch 181/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.0803 - mean_absolute_error: 0.1667 - val_loss: 0.4049 - val_mean_absolute_error: 0.2858
# Epoch 182/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.0814 - mean_absolute_error: 0.1705 - val_loss: 0.4184 - val_mean_absolute_error: 0.2319
# Epoch 183/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.0844 - mean_absolute_error: 0.1779 - val_loss: 0.4274 - val_mean_absolute_error: 0.2564
# Epoch 184/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.0811 - mean_absolute_error: 0.1725 - val_loss: 0.4029 - val_mean_absolute_error: 0.2483
# Epoch 185/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.0740 - mean_absolute_error: 0.1550 - val_loss: 0.4121 - val_mean_absolute_error: 0.2259
# Epoch 186/200
# 1157/1157 [==============================] - 0s 285us/sample - loss: 0.0834 - mean_absolute_error: 0.1779 - val_loss: 0.4484 - val_mean_absolute_error: 0.2794
# Epoch 187/200
# 1157/1157 [==============================] - 0s 278us/sample - loss: 0.0872 - mean_absolute_error: 0.1821 - val_loss: 0.4016 - val_mean_absolute_error: 0.2198
# Epoch 188/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0804 - mean_absolute_error: 0.1720 - val_loss: 0.4600 - val_mean_absolute_error: 0.2624
# Epoch 189/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.0755 - mean_absolute_error: 0.1586 - val_loss: 0.4118 - val_mean_absolute_error: 0.2223
# Epoch 190/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0838 - mean_absolute_error: 0.1771 - val_loss: 0.4065 - val_mean_absolute_error: 0.2204
# Epoch 191/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.0776 - mean_absolute_error: 0.1706 - val_loss: 0.4293 - val_mean_absolute_error: 0.3022
# Epoch 192/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.0796 - mean_absolute_error: 0.1720 - val_loss: 0.4419 - val_mean_absolute_error: 0.2636
# Epoch 193/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.0800 - mean_absolute_error: 0.1736 - val_loss: 0.4131 - val_mean_absolute_error: 0.2318
# Epoch 194/200
# 1157/1157 [==============================] - 0s 280us/sample - loss: 0.0819 - mean_absolute_error: 0.1754 - val_loss: 0.4611 - val_mean_absolute_error: 0.3049
# Epoch 195/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.0789 - mean_absolute_error: 0.1691 - val_loss: 0.4065 - val_mean_absolute_error: 0.2213
# Epoch 196/200
# 1157/1157 [==============================] - 0s 281us/sample - loss: 0.0852 - mean_absolute_error: 0.1875 - val_loss: 0.4425 - val_mean_absolute_error: 0.2356
# Epoch 197/200
# 1157/1157 [==============================] - 0s 284us/sample - loss: 0.0805 - mean_absolute_error: 0.1726 - val_loss: 0.4199 - val_mean_absolute_error: 0.3392
# Epoch 198/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.0832 - mean_absolute_error: 0.1813 - val_loss: 0.4719 - val_mean_absolute_error: 0.2923
# Epoch 199/200
# 1157/1157 [==============================] - 0s 279us/sample - loss: 0.0851 - mean_absolute_error: 0.1797 - val_loss: 0.4340 - val_mean_absolute_error: 0.2601
# Epoch 200/200
# 1157/1157 [==============================] - 0s 283us/sample - loss: 0.0845 - mean_absolute_error: 0.1813 - val_loss: 0.4048 - val_mean_absolute_error: 0.2357

# %%
pred = model.predict(test_feature)

# %%
model.evaluate(test_feature, test_label)
# Out:
# 134/134 [==============================] - 0s 52us/sample - loss: 4.0511e-04 - mean_absolute_error: 0.0197
# [0.0004051127253836994, 0.01970019]

# %%
plt.figure(figsize=(12,9))
plt.plot(test_label, label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()
